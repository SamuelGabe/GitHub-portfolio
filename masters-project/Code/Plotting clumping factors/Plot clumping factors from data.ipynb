# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
os.chdir('/Users/samgabe/Documents/University/Project/Data.nosync')

# %%
dmmlist = ['lambda', 'cold', 'hot', 'wdm1', 'wdm2', 'wdm3', 'wdm4']
dlim_lst = [50, 100, 200]
for dlim in dlim_lst:
    plt.figure(figsize=(7, 5))
    print('dlim =', dlim)
    zarr = [4.2, 4.8, 5.4, 6.0, 7.0, 8.0, 10.0]
    for dmm in dmmlist:
        data = np.loadtxt(f'Clumping Factor Data/{dmm}/{dmm} Dlim {dlim} for CR correct alpha.txt')
        zarr, clump = data[:, 0], data[:, 1]
        plt.plot(zarr, clump, linewidth=1., label=dmm)
    plt.legend()
    plt.show()
# Out:
# dlim = 50
# dlim = 100
# dlim = 200
